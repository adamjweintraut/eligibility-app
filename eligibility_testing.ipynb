# %%
from httpx import AsyncClient, Timeout
from loguru import logger
import pandas as pd
import nest_asyncio
nest_asyncio.apply()

# %%
async with AsyncClient() as client:
    try:
        response = await client.post(
            url='https://sandbox.onederful.co/sandbox/eligibility',
            headers={'Content-Type': 'application/json'},
            json={
                "subscriber": {               
                    "first_name": "TEST",               
                    "last_name": "PERSON",               
                    "dob": "01/01/2011",               
                    "member_id": "1234567890"           
                },           
                "provider": {               
                    "npi": "1234567890"           
                },           
                "payer": {               
                    "id": "AETNA_DENTAL_PLANS"         
                },           
                "version": "v2"       
            },
            timeout=Timeout(20.0)
        )
        response.raise_for_status()
        data = response.json()
    except Exception as err:
        logger.error(f'Error requesting eligibility: {err} Error type: {type(err).__name__}')

# %%
aetna_data = data

# %%
aetna_data
# Out:
# {'onederfulId': '1234567890',
#  'payer_uuid': '0987654321',
#  'patient': {'member_id': '1234567890',
#   'address': {'street1': '1234 ANY CT',
#    'city': 'NYC',
#    'zip': '11111',
#    'state': 'NY'},
#   'coverage': {'effective_date': '01/01/2024', 'status': 'active'},
#   'name': 'TEST PERSON',
#   'first_name': 'TEST',
#   'last_name': 'PERSON',
#   'dob': '01/01/2011'},
#  'subscriber': {'name': 'TEST PERSON',
#   'first_name': 'TEST',
#   'last_name': 'PERSON',
#   'dob': '01/01/2011',
#   'member_id': '1234567890',
#   'address': {'street1': '1234 ANY CT',
#    'city': 'NYC',
#    'zip': '11111',
#    'state': 'NY'},
#   'coverage': {'effective_date': '01/01/2024', 'status': 'active'}},
#  'plan': {'name': 'DENTAL',
#   'number': '12345',
#   'type': 'THE PLAN DENTAL PPO',
#   'group_number': '10001',
#   'state': 'GA',
#   'period': 'calendar'},
#  'deductible': [{'network': 'in_network',
#    'category': 'preventive',
#    'plan_period': 'calendar',
#    'amount': '0.00',
#    'coverage_level': 'individual'},
#   {'network': 'in_network',
#    'category': 'basic_and_major',
#    'plan_period': 'calendar',
#    'amount': '50.00',
#    'coverage_level': 'individual'},
#   {'network': 'in_network',
#    'category': 'preventive',
#    'plan_period': 'remaining',
#    'amount': '0.00',
#    'coverage_level': 'individual'},
#   {'network': 'in_network',
#    'category': 'basic_and_major',
#    'plan_period': 'remaining',
#    'amount': '50.00',
#    'coverage_level': 'individual'},
#   {'network': 'in_network',
#    'category': 'preventive',
#    'plan_period': 'calendar',
#    'amount': '0.00',
#    'coverage_level': 'family'},
#   {'network': 'in_network',
#    'category': 'basic_and_major',
#    'plan_period': 'calendar',
#    'amount': '150.00',
#    'coverage_level': 'family'},
#   {'network': 'in_network',
#    'category': 'preventive',
#    'plan_period': 'remaining',
#    'amount': '0.00',
#    'coverage_level': 'family'},
#   {'network': 'in_network',
#    'category': 'basic_and_major',
#    'plan_period': 'remaining',
#    'amount': '150.00',
#    'coverage_level': 'family'},
#   {'network': 'out_of_network',
#    'category': 'preventive',
#    'plan_period': 'calendar',
#    'amount': '0.00',
#    'coverage_level': 'individual'},
#   {'network': 'out_of_network',
#    'category': 'basic_and_major',
#    'plan_period': 'calendar',
#    'amount': '50.00',
#    'coverage_level': 'individual'},
#   {'network': 'out_of_network',
#    'category': 'preventive',
#    'plan_period': 'remaining',
#    'amount': '0.00',
#    'coverage_level': 'individual'},
#   {'network': 'out_of_network',
#    'category': 'basic_and_major',
#    'plan_period': 'remaining',
#    'amount': '50.00',
#    'coverage_level': 'individual'},
#   {'network': 'out_of_network',
#    'category': 'preventive',
#    'plan_period': 'calendar',
#    'amount': '0.00',
#    'coverage_level': 'family'},
#   {'network': 'out_of_network',
#    'category': 'basic_and_major',
#    'plan_period': 'calendar',
#    'amount': '150.00',
#    'coverage_level': 'family'},
#   {'network': 'out_of_network',
#    'category': 'preventive',
#    'plan_period': 'remaining',
#    'amount': '0.00',
#    'coverage_level': 'family'},
#   {'network': 'out_of_network',
#    'category': 'basic_and_major',
#    'plan_period': 'remaining',
#    'amount': '150.00',
#    'coverage_level': 'family'}],
#  'maximums': [{'network': 'in_network',
#    'category': 'orthodontics',
#    'plan_period': 'lifetime',
#    'amount': '1500.00'},
#   {'network': 'in_network',
#    'category': 'preventive_basic_and_major',
#    'plan_period': 'calendar',
#    'amount': '1500.00'},
#   {'network': 'in_network',
#    'category': 'orthodontics',
#    'plan_period': 'lifetime_remaining',
#    'amount': '1500.00'},
#   {'network': 'in_network',
#    'category': 'preventive_basic_and_major',
#    'plan_period': 'remaining',
#    'amount': '1280.00'},
#   {'network': 'out_of_network',
#    'category': 'orthodontics',
#    'plan_period': 'lifetime',
#    'amount': '1500.00'},
#   {'network': 'out_of_network',
#    'category': 'preventive_basic_and_major',
#    'plan_period': 'calendar',
#    'amount': '1500.00'},
#   {'network': 'out_of_network',
#    'category': 'orthodontics',
#    'plan_period': 'lifetime_remaining',
#    'amount': '1500.00'},
#   {'network': 'out_of_network',
#    'category': 'preventive_basic_and_major',
#    'plan_period': 'remaining',
#    'amount': '1280.00'}],
#  'coinsurance': [{'network': 'in_network',
#    'category': 'preventive',
#    'plan_period': 'calendar',
#    'percent': '100'},
#   {'network': 'in_network',
#    'category': 'basic',
#    'plan_period': 'calendar',
#    'percent': '90'},
#   {'network': 'in_network',
#    'category': 'major',
#    'plan_period': 'calendar',
#    'percent': '60'},
#   {'network': 'in_network',
#    'category': 'orthodontics',
#    'plan_period': 'lifetime',
#    'percent': '50'},
#   {'network': 'out_of_network',
#    'category': 'preventive',
#    'plan_period': 'calendar',
#    'percent': '100'},
#   {'network': 'out_of_network',
#    'category': 'basic',
#    'plan_period': 'calendar',
#    'percent': '90'},
#   {'network': 'out_of_network',
#    'category': 'major',
#    'plan_period': 'calendar',
#    'percent': '60'},
#   {'network': 'out_of_network',
#    'category': 'orthodontics',
#    'plan_period': 'lifetime',
#    'percent': '50'}],
#  'limitations': [{'category': 'preventive',
#    'service_type': 'examinations',
#    'limitation': '2 per calendar year',
#    'limitation_applies_to': ['D0120',
#     'D0145',
#     'D0150',
#     'D0160',
#     'D0170',
#     'D0180',
#     'D9430'],
#    'service_dates': [{'procedure_code': 'D0120',
#      'service_date': '01/01/2024'}],
#    'services_remaining': 1,
#    'disclaimers': ['D9430 is covered only if no other service is provided during the visit.',
#     'Maximum benefit payable for a D0150 submitted for an established patient may be based on a D0120.'],
#    'eligibility_details': [{'eligibility': 'ELIGIBLE', 'date': '11/27/2024'}]},
#   {'category': 'basic',
#    'service_type': 'limited_examinations',
#    'limitation': '2 per calendar year',
#    'limitation_applies_to': ['D0140'],
#    'service_dates': [{'procedure_code': 'D0120',
#      'service_date': '01/01/2024'}],
#    'services_remaining': 1,
#    'disclaimers': ['Limited oral evaluation is considered with or without other procedures on same date of service.'],
#    'eligibility_details': [{'eligibility': 'ELIGIBLE', 'date': '11/27/2024'}]},
#   {'category': 'preventive',
#    'service_type': 'full_mouth',
#    'limitation': '1 per 60 consecutive months to the exact day',
#    'limitation_applies_to': ['D0210',
#     'D0330',
#     'D0372',
#     'D0387',
#     'D0701',
#     'D0709'],
#    'services_remaining': 1,
#    'disclaimers': ['The maximum benefit payable for eligible x-rays on a given date of service is that of a full mouth series.',
#     'If the patient is not eligible for bitewings, benefits for a full mouth series will be reduced by the amount previously paid for the bitewings.',
#     'D0701 and D0709 are only payable when submitted by an x-ray facility.'],
#    'eligibility_details': [{'eligibility': 'ELIGIBLE', 'date': '11/27/2024'}]},
#   {'category': 'preventive',
#    'service_type': 'periapicals',
#    'limitation': '4 per calendar year',
#    'limitation_applies_to': ['D0220', 'D0230', 'D0374', 'D0389', 'D0707'],
#    'services_remaining': 4,
#    'disclaimers': ['The maximum benefit payable for eligible x-rays on a given date of service is that of a full mouth series.',
#     'D0707 is only payable when submitted by an x-ray facility.'],
#    'eligibility_details': [{'eligibility': 'ELIGIBLE', 'date': '11/27/2024'}]},
#   {'category': 'preventive',
#    'service_type': 'extraoral_x_rays',
#    'limitation': '2 per calendar year',
#    'limitation_applies_to': ['D0250', 'D0251', 'D0310', 'D0340', 'D0702'],
#    'services_remaining': 2,
#    'disclaimers': ['Cephalometric images for orthodontic purposes are covered under orthodontia benefits.',
#     'D0702 and D0705 are only payable when submitted by an x-ray facility.'],
#    'eligibility_details': [{'eligibility': 'ELIGIBLE', 'date': '11/27/2024'}]},
#   {'category': 'preventive',
#    'service_type': 'bitewings',
#    'limitation': '1 per calendar year',
#    'limitation_applies_to': ['D0270',
#     'D0272',
#     'D0273',
#     'D0274',
#     'D0277',
#     'D0373',
#     'D0388',
#     'D0708'],
#    'services_remaining': 1,
#    'disclaimers': ['For ages 12 and older, bitewings are limited to up to 4 bitewings per occurrence.',
#     'The maximum benefit payable for eligible x-rays on a given date of service is that of a full mouth series.',
#     'D0708 is only payable when submitted by an x-ray facility.'],
#    'eligibility_details': [{'eligibility': 'ELIGIBLE', 'date': '11/27/2024'}]},
#   {'category': 'preventive',
#    'service_type': 'prophylaxis',
#    'limitation': '2 per calendar year',
#    'limitation_applies_to': ['D1110', 'D1120'],
#    'service_dates': [{'procedure_code': 'D4910',
#      'service_date': '01/01/2024'}],
#    'services_remaining': 1,
#    'disclaimers': ['Not covered if less than 90 days have passed since active periodontal therapy was completed.',
#     'If under age 14, benefit limited to child prophylaxis (D1120)'],
#    'eligibility_details': [{'eligibility': 'ELIGIBLE', 'date': '11/27/2024'}]},
#   {'category': 'preventive',
#    'service_type': 'recement_space_maintainer',
#    'limitation': '1 per 24 consecutive months to the exact day',
#    'limitation_applies_to': ['D1551', 'D1552', 'D1553'],
#    'services_remaining': 0,
#    'disclaimers': ['Considered if at least 12 months since insertion of the space maintainer.',
#     'Considered only for dependent children under age 18'],
#    'eligibility_details': [{'eligibility': 'NOT_ELIGIBLE', 'location': 'UA'},
#     {'eligibility': 'NOT_ELIGIBLE', 'location': 'LA'}]},
#   {'category': 'preventive',
#    'service_type': 'periodontal_maintenance',
#    'limitation': '2 per calendar year',
#    'limitation_applies_to': ['D4910'],
#    'service_dates': [{'procedure_code': 'D4910',
#      'service_date': '01/01/2024'}],
#    'services_remaining': 1,
#    'disclaimers': ['Procedure is only covered if documentation in history of prior treatment for periodontal disease which was deemed dentally necessary. The following allowed procedures qualify a patient for a D4910: D4210, D4211, D4240, D4241, D4260, D4261, D4341, D4342, and D4910',
#     'This procedure is only covered by us if at least 90 days have passed since the qualifying periodontal therapy listed above was completed.',
#     'If treatment for periodontal disease was provided prior to coverage with us, this procedure is only covered by us if a statement of the qualifying procedure performed is provided along with the initial submission of the D4910.'],
#    'eligibility_details': [{'eligibility': 'ELIGIBLE', 'date': '11/27/2024'}]},
#   {'category': 'preventive',
#    'service_type': 'fluoride',
#    'limitation': '2 per calendar year',
#    'limitation_applies_to': ['D1208', 'D1206'],
#    'services_remaining': 0,
#    'disclaimers': ['Considered only for dependent children under age 18'],
#    'eligibility_details': [{'eligibility': 'NOT_ELIGIBLE'}]},
#   {'category': 'preventive',
#    'service_type': 'sealants',
#    'limitation': '1 per 36 consecutive months to the exact day',
#    'limitation_applies_to': ['D1351', 'D1352', 'D1353'],
#    'services_remaining': 0,
#    'disclaimers': ['Considered only for dependent children under age 18',
#     'Applicable only to the occlusal surface of first and second permanent molars.'],
#    'eligibility_details': [{'eligibility': 'NOT_ELIGIBLE', 'location': '2'},
#     {'eligibility': 'NOT_ELIGIBLE', 'location': '3'},
#     {'eligibility': 'NOT_ELIGIBLE', 'location': '14'},
#     {'eligibility': 'NOT_ELIGIBLE', 'location': '15'},
#     {'eligibility': 'NOT_ELIGIBLE', 'location': '18'},
#     {'eligibility': 'NOT_ELIGIBLE', 'location': '19'},
#     {'eligibility': 'NOT_ELIGIBLE', 'location': '30'},
#     {'eligibility': 'NOT_ELIGIBLE', 'location': '31'}]},
#   {'category': 'preventive',
#    'service_type': 'caries_arresting_medicament',
#    'limitation': 'Covered once per site per lifetime',
#    'limitation_applies_to': ['D1354'],
#    'services_remaining': 0,
#    'disclaimers': ['Covered for deciduous teeth only.'],
#    'eligibility_details': [{'eligibility': 'ELIGIBLE',
#      'date': '11/27/2024',
#      'location': 'A'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'B'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'C'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'D'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'E'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'F'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'G'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'H'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'I'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'J'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'K'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'L'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'M'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'N'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'O'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'P'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'Q'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'R'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'S'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'T'}]},
#   {'category': 'preventive',
#    'service_type': 'space_maintainers',
#    'limitation': 'Covered once per site per lifetime',
#    'limitation_applies_to': ['D1510',
#     'D1520',
#     'D1526',
#     'D1527',
#     'D1575',
#     'D1516',
#     'D1517'],
#    'services_remaining': 0,
#    'disclaimers': ['Considered only for dependent children under age 18'],
#    'eligibility_details': [{'eligibility': 'NOT_ELIGIBLE', 'location': 'UA'},
#     {'eligibility': 'NOT_ELIGIBLE', 'location': 'LA'}]},
#   {'category': 'basic',
#    'service_type': 'fillings',
#    'limitation': '1 replacement every 24 months to the exact day',
#    'limitation_applies_to': ['D2330',
#     'D2331',
#     'D2332',
#     'D2335',
#     'D2140',
#     'D2150',
#     'D2160',
#     'D2161',
#     'D2390',
#     'D2391',
#     'D2392',
#     'D2393',
#     'D2394'],
#    'services_remaining': 0,
#    'disclaimers': ['Composites are considered at an amalgam rate for posterior teeth which includes molars and pre-molars (bicuspids).',
#     'Mesial-lingual, distal-lingual, mesial-buccal, and distal buccal restorations for anterior teeth will be considered at the rate of a single surface restoration.',
#     'Multiple restorations on adjacent surfaces of the same tooth are considered connected and will be based on the rate for a single restoration reflecting the number of different surfaces.',
#     'Multiple restorations on the same surface of the same tooth are considered at the rate for a single surface restoration.',
#     'Restorations replacing tooth structure lost from abrasion, attrition, abfraction and erosion are not covered.',
#     'These services are subject to Individual and/or Consultant review.'],
#    'eligibility_details': [{'eligibility': 'ELIGIBLE',
#      'date': '11/27/2024',
#      'location': '1'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '2'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '3'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '4'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '5'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '6'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '7'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '8'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '9'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '10'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '11'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '12'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '13'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '14'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '15'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '16'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '17'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '18'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '19'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '20'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '21'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '22'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '23'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '24'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '25'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '26'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '27'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '28'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '29'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '30'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '31'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '32'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'A'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'B'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'C'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'D'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'E'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'F'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'G'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'H'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'I'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'J'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'K'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'L'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'M'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'N'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'O'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'P'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'Q'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'R'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'S'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'T'}]},
#   {'category': 'major',
#    'service_type': 'crowns_and_onlays',
#    'limitation': '1 replacement every 60 months to the exact day',
#    'limitation_applies_to': ['D2710',
#     'D2712',
#     'D2720',
#     'D2721',
#     'D2722',
#     'D2740',
#     'D2750',
#     'D2751',
#     'D2752',
#     'D2780',
#     'D2781',
#     'D2782',
#     'D2783',
#     'D2790',
#     'D2791',
#     'D2792',
#     'D2794',
#     'D2542',
#     'D2543',
#     'D2544',
#     'D2642',
#     'D2643',
#     'D2644',
#     'D2662',
#     'D2663',
#     'D2664',
#     'D2753'],
#    'services_remaining': 0,
#    'disclaimers': ['These services are subject to Individual and/or Consultant review.',
#     'Covered services are paid on seat date',
#     'Molars/Pre-molars are based upon the alternate benefit of a noble metal cast crown. Anterior teeth are based upon the alternate benefit of a porcelain fused to noble metal cast crown.',
#     'These codes are covered services only if placed to restore a tooth broken down due to tooth decay or injury resulting in the loss of tooth structure. (Injury does not include damage to teeth that results from chewing or biting food, substances or objects).',
#     '3/4 Crowns are not covered on anterior teeth. 3/4 Crown coverage is limited to Molar/Pre-molars.'],
#    'eligibility_details': [{'eligibility': 'ELIGIBLE',
#      'date': '11/27/2024',
#      'location': '1'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '2'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '3'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '4'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '5'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '6'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '7'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '8'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '9'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '10'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '11'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '12'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '13'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '14'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '15'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '16'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '17'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '18'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '19'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '20'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '21'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '22'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '23'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '24'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '25'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '26'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '27'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '28'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '29'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '30'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '31'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '32'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'A'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'B'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'C'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'D'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'E'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'F'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'G'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'H'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'I'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'J'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'K'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'L'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'M'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'N'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'O'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'P'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'Q'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'R'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'S'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'T'}]},
#   {'category': 'major',
#    'service_type': 'crown_repair',
#    'limitation': '1 per 24 consecutive months to the exact day',
#    'limitation_applies_to': ['D2980', 'D2981', 'D2982'],
#    'services_remaining': 0,
#    'disclaimers': ['Covered only if done more than 12 months after initial insertion of crown/onlay'],
#    'eligibility_details': [{'eligibility': 'ELIGIBLE',
#      'date': '11/27/2024',
#      'location': '1'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '2'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '3'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '4'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '5'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '6'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '7'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '8'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '9'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '10'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '11'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '12'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '13'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '14'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '15'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '16'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '17'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '18'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '19'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '20'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '21'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '22'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '23'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '24'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '25'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '26'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '27'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '28'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '29'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '30'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '31'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '32'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'A'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'B'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'C'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'D'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'E'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'F'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'G'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'H'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'I'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'J'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'K'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'L'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'M'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'N'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'O'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'P'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'Q'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'R'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'S'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'T'}]},
#   {'category': 'basic',
#    'service_type': 'stainless_steel_crowns',
#    'limitation': '1 replacement every 60 months to the exact day',
#    'limitation_applies_to': ['D2928',
#     'D2929',
#     'D2930',
#     'D2931',
#     'D2932',
#     'D2933',
#     'D2934'],
#    'services_remaining': 0,
#    'disclaimers': ['Crowns replacing tooth structure lost from abrasion, attrition, abfraction and erosion are not covered.',
#     'If used as a temporary, not covered',
#     'If a permanent crown replaces a stainless steel/resin/prefabricated crown at a later date but before replacement restrictions allow, all new charges will be reduced by those already paid.'],
#    'eligibility_details': [{'eligibility': 'ELIGIBLE',
#      'date': '11/27/2024',
#      'location': '1'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '2'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '3'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '4'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '5'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '6'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '7'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '8'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '9'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '10'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '11'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '12'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '13'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '14'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '15'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '16'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '17'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '18'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '19'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '20'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '21'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '22'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '23'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '24'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '25'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '26'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '27'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '28'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '29'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '30'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '31'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '32'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'A'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'B'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'C'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'D'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'E'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'F'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'G'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'H'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'I'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'J'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'K'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'L'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'M'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'N'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'O'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'P'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'Q'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'R'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'S'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'T'}]},
#   {'category': 'major',
#    'service_type': 'crown_recements',
#    'limitation': '1 per 24 consecutive months to the exact day',
#    'limitation_applies_to': ['D2920'],
#    'services_remaining': 0,
#    'disclaimers': ['Covered only if done more than 12 months after initial insertion of crown/onlay'],
#    'eligibility_details': [{'eligibility': 'ELIGIBLE',
#      'date': '11/27/2024',
#      'location': '1'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '2'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '3'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '4'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '5'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '6'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '7'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '8'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '9'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '10'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '11'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '12'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '13'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '14'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '15'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '16'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '17'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '18'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '19'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '20'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '21'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '22'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '23'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '24'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '25'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '26'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '27'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '28'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '29'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '30'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '31'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '32'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'A'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'B'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'C'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'D'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'E'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'F'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'G'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'H'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'I'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'J'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'K'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'L'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'M'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'N'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'O'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'P'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'Q'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'R'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'S'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'T'}]},
#   {'category': 'basic',
#    'service_type': 'protective_restorations',
#    'limitation': 'None',
#    'limitation_applies_to': ['D2940'],
#    'services_remaining': 2147483647,
#    'disclaimers': ['D2940 is covered only if not performed on the same date as the permanent restoration.',
#     'Not to be used to report endodontic access closure.'],
#    'eligibility_details': [{'eligibility': 'ELIGIBLE', 'date': '11/27/2024'}]},
#   {'category': 'major',
#    'service_type': 'buildups',
#    'limitation': '1 replacement every 60 months to the exact day',
#    'limitation_applies_to': ['D2950'],
#    'services_remaining': 0,
#    'disclaimers': ['These services are subject to Individual and/or Consultant review.',
#     'Considered only when required for retention and preservation of tooth. No benefits payable if restorative procedures are not covered.',
#     'Buildups submitted with the same date of service as a full cast crown are considered. Please bill for the crown on the seat date and for the buildup on the date it is performed.'],
#    'eligibility_details': [{'eligibility': 'ELIGIBLE',
#      'date': '11/27/2024',
#      'location': '1'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '2'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '3'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '4'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '5'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '6'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '7'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '8'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '9'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '10'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '11'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '12'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '13'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '14'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '15'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '16'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '17'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '18'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '19'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '20'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '21'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '22'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '23'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '24'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '25'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '26'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '27'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '28'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '29'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '30'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '31'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '32'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'A'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'B'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'C'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'D'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'E'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'F'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'G'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'H'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'I'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'J'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'K'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'L'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'M'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'N'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'O'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'P'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'Q'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'R'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'S'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'T'}]},
#   {'category': 'basic',
#    'service_type': 'pulpotomy',
#    'limitation': 'Covered once per site per lifetime',
#    'limitation_applies_to': ['D3220'],
#    'services_remaining': 0,
#    'disclaimers': ['Not to be construed as the first stage of root canal therapy.'],
#    'eligibility_details': [{'eligibility': 'ELIGIBLE',
#      'date': '11/27/2024',
#      'location': 'A'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'B'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'C'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'D'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'E'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'F'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'G'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'H'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'I'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'J'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'K'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'L'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'M'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'N'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'O'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'P'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'Q'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'R'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'S'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'T'}]},
#   {'category': 'basic',
#    'service_type': 'pulpal_therapy',
#    'limitation': 'None',
#    'limitation_applies_to': ['D3230', 'D3240'],
#    'services_remaining': 2147483647,
#    'disclaimers': ['Covered for deciduous teeth only.'],
#    'eligibility_details': [{'eligibility': 'ELIGIBLE', 'date': '11/27/2024'}]},
#   {'category': 'basic',
#    'service_type': 'incomplete_endodontic_therapy',
#    'limitation': 'Other',
#    'limitation_applies_to': ['D3332'],
#    'services_remaining': 0,
#    'disclaimers': ['Please provide diagnostic x-rays and a narrative or office notes for review.'],
#    'eligibility_details': [{'eligibility': 'ELIGIBLE', 'date': '11/27/2024'}]},
#   {'category': 'basic',
#    'service_type': 'treatment_of_root_canal_obstruction',
#    'limitation': 'Other',
#    'limitation_applies_to': ['D3331'],
#    'services_remaining': 0,
#    'disclaimers': ['Please provide diagnostic x-rays and a narrative or office notes for review.'],
#    'eligibility_details': [{'eligibility': 'ELIGIBLE', 'date': '11/27/2024'}]},
#   {'category': 'basic',
#    'service_type': 'simple_endodontic_therapy',
#    'limitation': 'Covered once per site per lifetime',
#    'limitation_applies_to': ['D3310', 'D3320'],
#    'services_remaining': 0,
#    'disclaimers': ['Includes intra-operative x-rays.'],
#    'eligibility_details': [{'eligibility': 'ELIGIBLE',
#      'date': '11/27/2024',
#      'location': '1'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '2'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '3'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '4'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '5'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '6'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '7'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '8'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '9'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '10'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '11'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '12'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '13'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '14'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '15'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '16'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '17'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '18'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '19'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '20'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '21'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '22'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '23'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '24'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '25'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '26'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '27'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '28'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '29'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '30'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '31'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '32'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'A'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'B'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'C'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'D'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'E'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'F'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'G'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'H'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'I'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'J'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'K'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'L'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'M'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'N'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'O'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'P'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'Q'},
# ...
#    'eligibility_details': [{'eligibility': 'ELIGIBLE', 'date': '11/27/2024'}]},
#   {'category': 'orthodontics',
#    'service_type': 'noncovered_orthodontic_services',
#    'limitation': 'NA',
#    'limitation_applies_to': ['D8692', 'D8695'],
#    'services_remaining': 0,
#    'eligibility_details': [{'eligibility': 'NOT_ELIGIBLE'}]},
#   {'category': 'basic',
#    'service_type': 'palliative_treatment',
#    'limitation': 'NA',
#    'limitation_applies_to': ['D9110'],
#    'services_remaining': 0,
#    'disclaimers': ['Covered only if no other service (except x-rays) is provided during the visit',
#     'There is no age limitation for palliative treatments.'],
#    'eligibility_details': [{'eligibility': 'ELIGIBLE', 'date': '11/27/2024'}]},
#   {'category': 'basic',
#    'service_type': 'general_anesthesia',
#    'limitation': 'Other',
#    'limitation_applies_to': ['D9222', 'D9223', 'D9239', 'D9243'],
#    'services_remaining': 0,
#    'disclaimers': ['These services are subject to Individual and/or Consultant review based on service, complexity, and length of procedure.',
#     'General Anesthesia or IV Sedation is payable for: removal of impacted teeth or coronectomy, the removal of residual tooth roots and/or the surgical removal of 4 molars on the same day in four different quadrants',
#     'General Anesthesia or IV Sedation is also payable for: removal of dental cysts/tumors, multiple restorative services for Children under age 5, osseous surgery, bone grafting, removal of third molars in 3 or 4 different quadrants on the same day',
#     "General Anesthesia or IV Sedation isn't covered when: used for more than one hour, the service isn't covered, used for patient management.",
#     'A predetermination is recommended.'],
#    'eligibility_details': [{'eligibility': 'ELIGIBLE', 'date': '11/27/2024'}]},
#   {'category': 'basic',
#    'service_type': 'therapeutic_parenteral_drugs',
#    'limitation': 'Other',
#    'limitation_applies_to': ['D9610', 'D9612'],
#    'services_remaining': 0,
#    'disclaimers': ['Covered for antibiotic drug administration only. Please submit the name of the drug for review.',
#     'Covered only if performed in conjunction with General Anesthesia or IV Sedation.'],
#    'eligibility_details': [{'eligibility': 'ELIGIBLE', 'date': '11/27/2024'}]},
#   {'category': 'basic',
#    'service_type': 'consultations',
#    'limitation': '1 per 12 consecutive months to the exact day',
#    'limitation_applies_to': ['D9310'],
#    'services_remaining': 1,
#    'disclaimers': ['Limited to a specialist',
#     'Covered only if no other service (except x-rays) is provided during the visit'],
#    'eligibility_details': [{'eligibility': 'ELIGIBLE', 'date': '11/27/2024'}]},
#   {'category': 'basic',
#    'service_type': 'occlusal_guards',
#    'limitation': '1 per 36 consecutive months to the exact day',
#    'limitation_applies_to': ['D9944', 'D9945', 'D9946'],
#    'services_remaining': 1,
#    'eligibility_details': [{'eligibility': 'ELIGIBLE', 'date': '11/27/2024'}]},
#   {'category': 'preventive',
#    'service_type': 'occlusal_x_rays',
#    'limitation': '2 per calendar year',
#    'limitation_applies_to': ['D0240', 'D0706'],
#    'services_remaining': 2,
#    'disclaimers': ['D0706 is only payable when submitted by an x-ray facility.'],
#    'eligibility_details': [{'eligibility': 'ELIGIBLE', 'date': '11/27/2024'}]},
#   {'category': 'orthodontics',
#    'service_type': 'oral_facial_images',
#    'limitation': 'None',
#    'limitation_applies_to': ['D0350', 'D0703'],
#    'services_remaining': 2147483647,
#    'disclaimers': ['Photos/images for orthodontic purposes are considered under orthodontia benefits. Refer to Orthodontia benefits for more details.',
#     'Only one occurrence is payable on a single date of service.',
#     'D0703 is only payable when submitted by an x-ray facility.'],
#    'eligibility_details': [{'eligibility': 'ELIGIBLE', 'date': '11/27/2024'}]},
#   {'category': 'major',
#    'service_type': 'surgical_access_of_an_unerupted_tooth',
#    'limitation': 'Other',
#    'limitation_applies_to': ['D7280'],
#    'services_remaining': 0,
#    'eligibility_details': [{'eligibility': 'ELIGIBLE', 'date': '11/27/2024'}]},
#   {'category': 'major',
#    'service_type': 'placement_of_device_to_facilitate_eruption',
#    'limitation': 'Other',
#    'limitation_applies_to': ['D7283'],
#    'services_remaining': 0,
#    'eligibility_details': [{'eligibility': 'ELIGIBLE', 'date': '11/27/2024'}]},
#   {'category': 'basic',
#    'service_type': 'pin_retention',
#    'limitation': 'None',
#    'limitation_applies_to': ['D2951'],
#    'services_remaining': 2147483647,
#    'disclaimers': ['Covered only if submitted on the same date of service and same tooth as a crown or a 3+ surface filling, inlay, or onlay.',
#     'Only one occurrence per tooth is payable on a single date of service.'],
#    'eligibility_details': [{'eligibility': 'ELIGIBLE', 'date': '11/27/2024'}]},
#   {'category': 'major',
#    'service_type': 'post_and_cores',
#    'limitation': '1 replacement every 60 months to the exact day',
#    'limitation_applies_to': ['D2952', 'D2953', 'D2954', 'D2957'],
#    'services_remaining': 0,
#    'disclaimers': ['Post and Core is not payable unless there is history of root canal therapy.',
#     'Post and Core is not payable if restorative procedure is not covered.',
#     'These services are subject to Individual and/or Consultant review.',
#     'Indirectly fabricated post and core is considered at the prefabricated post and core rate.'],
#    'eligibility_details': [{'eligibility': 'ELIGIBLE',
#      'date': '11/27/2024',
#      'location': '1'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '2'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '3'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '4'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '5'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '6'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '7'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '8'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '9'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '10'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '11'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '12'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '13'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '14'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '15'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '16'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '17'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '18'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '19'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '20'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '21'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '22'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '23'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '24'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '25'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '26'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '27'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '28'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '29'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '30'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '31'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '32'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'A'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'B'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'C'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'D'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'E'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'F'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'G'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'H'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'I'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'J'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'K'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'L'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'M'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'N'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'O'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'P'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'Q'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'R'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'S'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'T'}]},
#   {'category': 'major',
#    'service_type': 'post_removal',
#    'limitation': 'None',
#    'limitation_applies_to': ['D2955'],
#    'services_remaining': 2147483647,
#    'disclaimers': ['Please submit diagnostic x-rays for review.',
#     'These services are subject to Individual and/or Consultant review.'],
#    'eligibility_details': [{'eligibility': 'ELIGIBLE', 'date': '11/27/2024'}]},
#   {'category': 'major',
#    'service_type': 'frenulectomy',
#    'limitation': 'Other',
#    'limitation_applies_to': ['D7961', 'D7963'],
#    'services_remaining': 0,
#    'disclaimers': ['These services are subject to Individual and/or Consultant review.',
#     'Please provide x-rays, photos, and clinical narrative for review.'],
#    'eligibility_details': [{'eligibility': 'ELIGIBLE', 'date': '11/27/2024'}]},
#   {'category': 'major',
#    'service_type': 'lingual_frenulectomy',
#    'limitation': 'Other',
#    'limitation_applies_to': ['D7962'],
#    'services_remaining': 0,
#    'disclaimers': ['These services are subject to Individual and/or Consultant review.',
#     'Please provide x-rays, photos, and clinical narrative for review.'],
#    'eligibility_details': [{'eligibility': 'ELIGIBLE', 'date': '11/27/2024'}]},
#   {'category': 'major',
#    'service_type': 'alveoplasty',
#    'limitation': 'Other',
#    'limitation_applies_to': ['D7310', 'D7311', 'D7320', 'D7321'],
#    'services_remaining': 0,
#    'disclaimers': ['These services are subject to Individual and/or Consultant review.',
#     'Radiographs must verify need to substantially reshape alveolar bone in preparation for a fixed or removable prosthetic'],
#    'eligibility_details': [{'eligibility': 'ELIGIBLE', 'date': '11/27/2024'}]},
#   {'category': 'basic',
#    'service_type': 'soft_biopsy',
#    'limitation': 'Other',
#    'limitation_applies_to': ['D7284', 'D7286', 'D7288'],
#    'services_remaining': 0,
#    'disclaimers': ['We do not cover biopsies of the lip, cheek, tongue, or any area outside of the oral cavity.',
#     'Please provide a path report, description and location of the procedure performed and x-rays or photos.'],
#    'eligibility_details': [{'eligibility': 'ELIGIBLE', 'date': '11/27/2024'}]},
#   {'category': 'major',
#    'service_type': 'hard_biopsy',
#    'limitation': 'Other',
#    'limitation_applies_to': ['D7285'],
#    'services_remaining': 0,
#    'disclaimers': ['We do not cover biopsies of the lip, cheek, tongue, or any area outside of the oral cavity.',
#     'Please provide a path report, description and location of the procedure performed and x-rays or photos.'],
#    'eligibility_details': [{'eligibility': 'ELIGIBLE', 'date': '11/27/2024'}]},
#   {'category': 'basic',
#    'service_type': 'incision_and_drainage_abscess',
#    'limitation': 'Other',
#    'limitation_applies_to': ['D7510'],
#    'services_remaining': 0,
#    'disclaimers': ['A separate benefit is not considered if done on the same day as an extraction.'],
#    'eligibility_details': [{'eligibility': 'ELIGIBLE', 'date': '11/27/2024'}]},
#   {'category': 'basic',
#    'service_type': 'pulp_vitality_tests',
#    'limitation': 'Other',
#    'limitation_applies_to': ['D0460'],
#    'services_remaining': 0,
#    'disclaimers': ['We allow one D0460 per date of service.'],
#    'eligibility_details': [{'eligibility': 'ELIGIBLE',
#      'date': '11/27/2024'}]}],
#  'not_covered': [{'category': 'not_covered',
#    'service_type': 'implant_body',
#    'limitation_applies_to': ['D6010', 'D6013', 'D6040', 'D6050']},
#   {'category': 'not_covered',
#    'service_type': 'implant_supporting_structures',
#    'limitation_applies_to': ['D6056', 'D6057']},
#   {'category': 'not_covered',
#    'service_type': 'bone_replacement_graft_at_the_time_of_implant',
#    'limitation_applies_to': ['D6104']},
#   {'category': 'not_covered',
#    'service_type': 'implant_removal',
#    'limitation_applies_to': ['D6100', 'D6105']},
#   {'category': 'not_covered',
#    'service_type': 'implant_supported_connecting_bar',
#    'limitation_applies_to': ['D6055']},
#   {'category': 'not_covered',
#    'service_type': 'maintenance_or_scaling_and_debridement_of_an_implant',
#    'limitation_applies_to': ['D6080', 'D6081']},
#   {'category': 'not_covered',
#    'service_type': 'repair_implant_abutment_remove_broken_implant_screw',
#    'limitation_applies_to': ['D6089', 'D6095', 'D6096', 'D6197']},
#   {'category': 'not_covered',
#    'service_type': 'treatment_of_peri_implant_defect',
#    'limitation_applies_to': ['D6101', 'D6102', 'D6103']},
#   {'category': 'not_covered',
#    'service_type': 'harmful_habit_appliance',
#    'limitation_applies_to': ['D8210', 'D8220'],
#    'disclaimers': ['Considered only for dependent children under age 18']},
#   {'category': 'not_covered',
#    'service_type': 'bone_replacement_graft_ridge_preservation',
#    'limitation_applies_to': ['D7953'],
#    'disclaimers': ['This bone graft code should not be billed if the tooth is still present.']},
#   {'category': 'not_covered',
#    'service_type': 'non_covered',
#    'limitation_applies_to': ['D0171',
#     'D0367',
#     'D0431',
#     'D1330',
#     'D2962',
#     'D3110',
#     'D3120',
#     'D3911',
#     'D4266',
#     'D4322',
#     'D4323',
#     'D4381',
#     'D5820',
#     'D5821',
#     'D6198',
#     'D7298',
#     'D7299',
#     'D7300',
#     'D7880',
#     'D7950',
#     'D7951',
#     'D7952',
#     'D9230',
#     'D9248',
#     'D9912',
#     'D9941',
#     'D9947',
#     'D9948',
#     'D9949',
#     'D9995',
#     'D9996'],
#    'disclaimers': ['This is a list of commonly asked about codes that are not covered. This is not an all-inclusive list of non-covered codes.',
#     'Payer does not provide benefits for any treatment or service that is: primarily cosmetic, temporary, replacing tooth structure lost from abrasion, attrition, erosion or abfraction, not reasonably expected to successfully correct a dental condition for at least 3 years']}],
#  'disclaimers': ['This plan has a missing tooth clause that may apply to the initial placement of full or partial dentures, fixed bridges, implants, and implant crowns. A predetermination is recommended to determine benefits.',
#   'The patient should see an In Network dentist for the best benefit. Lesser benefits are available by visiting a non-participating dentist. A different fee schedule may apply according to leased agreements. Benefits for non-participating Dentists are subject to Usual, Customary and Reasonable Fees (UCR). Call 800-247-4695 to check participation.',
#   'Predeterminations are not required prior to services being rendered. A predetermination may be recommended for certain services',
#   'Coordination of Benefits are determined by the Standard/Birthday Rule as defined by NAIC',
#   'Implants are allowed for patients 16 and over only.',
#   'Dependent dental will be terminated when dependent has turned 26 years old.',
#   'Orthodontic treatment is considered for all persons, regardless of age.']}

# %%
data1 = data

# %%
# data1.values()

# %%
data1
# Out:
# {'onederfulId': '1234567890',
#  'payer_uuid': '0987654321',
#  'patient': {'member_id': '1234567890',
#   'address': {'street1': '1234 ANY CT',
#    'city': 'NYC',
#    'zip': '11111',
#    'state': 'NY'},
#   'coverage': {'effective_date': '01/01/2024', 'status': 'active'},
#   'name': 'TEST PERSON',
#   'first_name': 'TEST',
#   'last_name': 'PERSON',
#   'dob': '01/01/2011'},
#  'subscriber': {'name': 'TEST PERSON',
#   'first_name': 'TEST',
#   'last_name': 'PERSON',
#   'dob': '01/01/2011',
#   'member_id': '1234567890',
#   'address': {'street1': '1234 ANY CT',
#    'city': 'NYC',
#    'zip': '11111',
#    'state': 'NY'},
#   'coverage': {'effective_date': '01/01/2024', 'status': 'active'}},
#  'plan': {'name': 'DENTAL',
#   'number': '12345',
#   'type': 'THE PLAN DENTAL PPO',
#   'group_number': '10001',
#   'state': 'GA',
#   'period': 'calendar'},
#  'deductible': [{'network': 'in_network',
#    'category': 'preventive',
#    'plan_period': 'calendar',
#    'amount': '0.00',
#    'coverage_level': 'individual'},
#   {'network': 'in_network',
#    'category': 'basic_and_major',
#    'plan_period': 'calendar',
#    'amount': '50.00',
#    'coverage_level': 'individual'},
#   {'network': 'in_network',
#    'category': 'preventive',
#    'plan_period': 'remaining',
#    'amount': '0.00',
#    'coverage_level': 'individual'},
#   {'network': 'in_network',
#    'category': 'basic_and_major',
#    'plan_period': 'remaining',
#    'amount': '50.00',
#    'coverage_level': 'individual'},
#   {'network': 'in_network',
#    'category': 'preventive',
#    'plan_period': 'calendar',
#    'amount': '0.00',
#    'coverage_level': 'family'},
#   {'network': 'in_network',
#    'category': 'basic_and_major',
#    'plan_period': 'calendar',
#    'amount': '150.00',
#    'coverage_level': 'family'},
#   {'network': 'in_network',
#    'category': 'preventive',
#    'plan_period': 'remaining',
#    'amount': '0.00',
#    'coverage_level': 'family'},
#   {'network': 'in_network',
#    'category': 'basic_and_major',
#    'plan_period': 'remaining',
#    'amount': '150.00',
#    'coverage_level': 'family'},
#   {'network': 'out_of_network',
#    'category': 'preventive',
#    'plan_period': 'calendar',
#    'amount': '0.00',
#    'coverage_level': 'individual'},
#   {'network': 'out_of_network',
#    'category': 'basic_and_major',
#    'plan_period': 'calendar',
#    'amount': '50.00',
#    'coverage_level': 'individual'},
#   {'network': 'out_of_network',
#    'category': 'preventive',
#    'plan_period': 'remaining',
#    'amount': '0.00',
#    'coverage_level': 'individual'},
#   {'network': 'out_of_network',
#    'category': 'basic_and_major',
#    'plan_period': 'remaining',
#    'amount': '50.00',
#    'coverage_level': 'individual'},
#   {'network': 'out_of_network',
#    'category': 'preventive',
#    'plan_period': 'calendar',
#    'amount': '0.00',
#    'coverage_level': 'family'},
#   {'network': 'out_of_network',
#    'category': 'basic_and_major',
#    'plan_period': 'calendar',
#    'amount': '150.00',
#    'coverage_level': 'family'},
#   {'network': 'out_of_network',
#    'category': 'preventive',
#    'plan_period': 'remaining',
#    'amount': '0.00',
#    'coverage_level': 'family'},
#   {'network': 'out_of_network',
#    'category': 'basic_and_major',
#    'plan_period': 'remaining',
#    'amount': '150.00',
#    'coverage_level': 'family'}],
#  'maximums': [{'network': 'in_network',
#    'category': 'orthodontics',
#    'plan_period': 'lifetime',
#    'amount': '1500.00'},
#   {'network': 'in_network',
#    'category': 'preventive_basic_and_major',
#    'plan_period': 'calendar',
#    'amount': '1500.00'},
#   {'network': 'in_network',
#    'category': 'orthodontics',
#    'plan_period': 'lifetime_remaining',
#    'amount': '1500.00'},
#   {'network': 'in_network',
#    'category': 'preventive_basic_and_major',
#    'plan_period': 'remaining',
#    'amount': '1280.00'},
#   {'network': 'out_of_network',
#    'category': 'orthodontics',
#    'plan_period': 'lifetime',
#    'amount': '1500.00'},
#   {'network': 'out_of_network',
#    'category': 'preventive_basic_and_major',
#    'plan_period': 'calendar',
#    'amount': '1500.00'},
#   {'network': 'out_of_network',
#    'category': 'orthodontics',
#    'plan_period': 'lifetime_remaining',
#    'amount': '1500.00'},
#   {'network': 'out_of_network',
#    'category': 'preventive_basic_and_major',
#    'plan_period': 'remaining',
#    'amount': '1280.00'}],
#  'coinsurance': [{'network': 'in_network',
#    'category': 'preventive',
#    'plan_period': 'calendar',
#    'percent': '100'},
#   {'network': 'in_network',
#    'category': 'basic',
#    'plan_period': 'calendar',
#    'percent': '90'},
#   {'network': 'in_network',
#    'category': 'major',
#    'plan_period': 'calendar',
#    'percent': '60'},
#   {'network': 'in_network',
#    'category': 'orthodontics',
#    'plan_period': 'lifetime',
#    'percent': '50'},
#   {'network': 'out_of_network',
#    'category': 'preventive',
#    'plan_period': 'calendar',
#    'percent': '100'},
#   {'network': 'out_of_network',
#    'category': 'basic',
#    'plan_period': 'calendar',
#    'percent': '90'},
#   {'network': 'out_of_network',
#    'category': 'major',
#    'plan_period': 'calendar',
#    'percent': '60'},
#   {'network': 'out_of_network',
#    'category': 'orthodontics',
#    'plan_period': 'lifetime',
#    'percent': '50'}],
#  'limitations': [{'category': 'preventive',
#    'service_type': 'examinations',
#    'limitation': '2 per calendar year',
#    'limitation_applies_to': ['D0120',
#     'D0145',
#     'D0150',
#     'D0160',
#     'D0170',
#     'D0180',
#     'D9430'],
#    'service_dates': [{'procedure_code': 'D0120',
#      'service_date': '01/01/2024'}],
#    'services_remaining': 1,
#    'disclaimers': ['D9430 is covered only if no other service is provided during the visit.',
#     'Maximum benefit payable for a D0150 submitted for an established patient may be based on a D0120.'],
#    'eligibility_details': [{'eligibility': 'ELIGIBLE', 'date': '11/27/2024'}]},
#   {'category': 'basic',
#    'service_type': 'limited_examinations',
#    'limitation': '2 per calendar year',
#    'limitation_applies_to': ['D0140'],
#    'service_dates': [{'procedure_code': 'D0120',
#      'service_date': '01/01/2024'}],
#    'services_remaining': 1,
#    'disclaimers': ['Limited oral evaluation is considered with or without other procedures on same date of service.'],
#    'eligibility_details': [{'eligibility': 'ELIGIBLE', 'date': '11/27/2024'}]},
#   {'category': 'preventive',
#    'service_type': 'full_mouth',
#    'limitation': '1 per 60 consecutive months to the exact day',
#    'limitation_applies_to': ['D0210',
#     'D0330',
#     'D0372',
#     'D0387',
#     'D0701',
#     'D0709'],
#    'services_remaining': 1,
#    'disclaimers': ['The maximum benefit payable for eligible x-rays on a given date of service is that of a full mouth series.',
#     'If the patient is not eligible for bitewings, benefits for a full mouth series will be reduced by the amount previously paid for the bitewings.',
#     'D0701 and D0709 are only payable when submitted by an x-ray facility.'],
#    'eligibility_details': [{'eligibility': 'ELIGIBLE', 'date': '11/27/2024'}]},
#   {'category': 'preventive',
#    'service_type': 'periapicals',
#    'limitation': '4 per calendar year',
#    'limitation_applies_to': ['D0220', 'D0230', 'D0374', 'D0389', 'D0707'],
#    'services_remaining': 4,
#    'disclaimers': ['The maximum benefit payable for eligible x-rays on a given date of service is that of a full mouth series.',
#     'D0707 is only payable when submitted by an x-ray facility.'],
#    'eligibility_details': [{'eligibility': 'ELIGIBLE', 'date': '11/27/2024'}]},
#   {'category': 'preventive',
#    'service_type': 'extraoral_x_rays',
#    'limitation': '2 per calendar year',
#    'limitation_applies_to': ['D0250', 'D0251', 'D0310', 'D0340', 'D0702'],
#    'services_remaining': 2,
#    'disclaimers': ['Cephalometric images for orthodontic purposes are covered under orthodontia benefits.',
#     'D0702 and D0705 are only payable when submitted by an x-ray facility.'],
#    'eligibility_details': [{'eligibility': 'ELIGIBLE', 'date': '11/27/2024'}]},
#   {'category': 'preventive',
#    'service_type': 'bitewings',
#    'limitation': '1 per calendar year',
#    'limitation_applies_to': ['D0270',
#     'D0272',
#     'D0273',
#     'D0274',
#     'D0277',
#     'D0373',
#     'D0388',
#     'D0708'],
#    'services_remaining': 1,
#    'disclaimers': ['For ages 12 and older, bitewings are limited to up to 4 bitewings per occurrence.',
#     'The maximum benefit payable for eligible x-rays on a given date of service is that of a full mouth series.',
#     'D0708 is only payable when submitted by an x-ray facility.'],
#    'eligibility_details': [{'eligibility': 'ELIGIBLE', 'date': '11/27/2024'}]},
#   {'category': 'preventive',
#    'service_type': 'prophylaxis',
#    'limitation': '2 per calendar year',
#    'limitation_applies_to': ['D1110', 'D1120'],
#    'service_dates': [{'procedure_code': 'D4910',
#      'service_date': '01/01/2024'}],
#    'services_remaining': 1,
#    'disclaimers': ['Not covered if less than 90 days have passed since active periodontal therapy was completed.',
#     'If under age 14, benefit limited to child prophylaxis (D1120)'],
#    'eligibility_details': [{'eligibility': 'ELIGIBLE', 'date': '11/27/2024'}]},
#   {'category': 'preventive',
#    'service_type': 'recement_space_maintainer',
#    'limitation': '1 per 24 consecutive months to the exact day',
#    'limitation_applies_to': ['D1551', 'D1552', 'D1553'],
#    'services_remaining': 0,
#    'disclaimers': ['Considered if at least 12 months since insertion of the space maintainer.',
#     'Considered only for dependent children under age 18'],
#    'eligibility_details': [{'eligibility': 'NOT_ELIGIBLE', 'location': 'UA'},
#     {'eligibility': 'NOT_ELIGIBLE', 'location': 'LA'}]},
#   {'category': 'preventive',
#    'service_type': 'periodontal_maintenance',
#    'limitation': '2 per calendar year',
#    'limitation_applies_to': ['D4910'],
#    'service_dates': [{'procedure_code': 'D4910',
#      'service_date': '01/01/2024'}],
#    'services_remaining': 1,
#    'disclaimers': ['Procedure is only covered if documentation in history of prior treatment for periodontal disease which was deemed dentally necessary. The following allowed procedures qualify a patient for a D4910: D4210, D4211, D4240, D4241, D4260, D4261, D4341, D4342, and D4910',
#     'This procedure is only covered by us if at least 90 days have passed since the qualifying periodontal therapy listed above was completed.',
#     'If treatment for periodontal disease was provided prior to coverage with us, this procedure is only covered by us if a statement of the qualifying procedure performed is provided along with the initial submission of the D4910.'],
#    'eligibility_details': [{'eligibility': 'ELIGIBLE', 'date': '11/27/2024'}]},
#   {'category': 'preventive',
#    'service_type': 'fluoride',
#    'limitation': '2 per calendar year',
#    'limitation_applies_to': ['D1208', 'D1206'],
#    'services_remaining': 0,
#    'disclaimers': ['Considered only for dependent children under age 18'],
#    'eligibility_details': [{'eligibility': 'NOT_ELIGIBLE'}]},
#   {'category': 'preventive',
#    'service_type': 'sealants',
#    'limitation': '1 per 36 consecutive months to the exact day',
#    'limitation_applies_to': ['D1351', 'D1352', 'D1353'],
#    'services_remaining': 0,
#    'disclaimers': ['Considered only for dependent children under age 18',
#     'Applicable only to the occlusal surface of first and second permanent molars.'],
#    'eligibility_details': [{'eligibility': 'NOT_ELIGIBLE', 'location': '2'},
#     {'eligibility': 'NOT_ELIGIBLE', 'location': '3'},
#     {'eligibility': 'NOT_ELIGIBLE', 'location': '14'},
#     {'eligibility': 'NOT_ELIGIBLE', 'location': '15'},
#     {'eligibility': 'NOT_ELIGIBLE', 'location': '18'},
#     {'eligibility': 'NOT_ELIGIBLE', 'location': '19'},
#     {'eligibility': 'NOT_ELIGIBLE', 'location': '30'},
#     {'eligibility': 'NOT_ELIGIBLE', 'location': '31'}]},
#   {'category': 'preventive',
#    'service_type': 'caries_arresting_medicament',
#    'limitation': 'Covered once per site per lifetime',
#    'limitation_applies_to': ['D1354'],
#    'services_remaining': 0,
#    'disclaimers': ['Covered for deciduous teeth only.'],
#    'eligibility_details': [{'eligibility': 'ELIGIBLE',
#      'date': '11/27/2024',
#      'location': 'A'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'B'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'C'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'D'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'E'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'F'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'G'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'H'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'I'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'J'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'K'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'L'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'M'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'N'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'O'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'P'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'Q'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'R'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'S'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'T'}]},
#   {'category': 'preventive',
#    'service_type': 'space_maintainers',
#    'limitation': 'Covered once per site per lifetime',
#    'limitation_applies_to': ['D1510',
#     'D1520',
#     'D1526',
#     'D1527',
#     'D1575',
#     'D1516',
#     'D1517'],
#    'services_remaining': 0,
#    'disclaimers': ['Considered only for dependent children under age 18'],
#    'eligibility_details': [{'eligibility': 'NOT_ELIGIBLE', 'location': 'UA'},
#     {'eligibility': 'NOT_ELIGIBLE', 'location': 'LA'}]},
#   {'category': 'basic',
#    'service_type': 'fillings',
#    'limitation': '1 replacement every 24 months to the exact day',
#    'limitation_applies_to': ['D2330',
#     'D2331',
#     'D2332',
#     'D2335',
#     'D2140',
#     'D2150',
#     'D2160',
#     'D2161',
#     'D2390',
#     'D2391',
#     'D2392',
#     'D2393',
#     'D2394'],
#    'services_remaining': 0,
#    'disclaimers': ['Composites are considered at an amalgam rate for posterior teeth which includes molars and pre-molars (bicuspids).',
#     'Mesial-lingual, distal-lingual, mesial-buccal, and distal buccal restorations for anterior teeth will be considered at the rate of a single surface restoration.',
#     'Multiple restorations on adjacent surfaces of the same tooth are considered connected and will be based on the rate for a single restoration reflecting the number of different surfaces.',
#     'Multiple restorations on the same surface of the same tooth are considered at the rate for a single surface restoration.',
#     'Restorations replacing tooth structure lost from abrasion, attrition, abfraction and erosion are not covered.',
#     'These services are subject to Individual and/or Consultant review.'],
#    'eligibility_details': [{'eligibility': 'ELIGIBLE',
#      'date': '11/27/2024',
#      'location': '1'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '2'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '3'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '4'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '5'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '6'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '7'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '8'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '9'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '10'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '11'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '12'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '13'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '14'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '15'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '16'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '17'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '18'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '19'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '20'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '21'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '22'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '23'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '24'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '25'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '26'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '27'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '28'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '29'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '30'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '31'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '32'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'A'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'B'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'C'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'D'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'E'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'F'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'G'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'H'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'I'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'J'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'K'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'L'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'M'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'N'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'O'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'P'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'Q'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'R'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'S'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'T'}]},
#   {'category': 'major',
#    'service_type': 'crowns_and_onlays',
#    'limitation': '1 replacement every 60 months to the exact day',
#    'limitation_applies_to': ['D2710',
#     'D2712',
#     'D2720',
#     'D2721',
#     'D2722',
#     'D2740',
#     'D2750',
#     'D2751',
#     'D2752',
#     'D2780',
#     'D2781',
#     'D2782',
#     'D2783',
#     'D2790',
#     'D2791',
#     'D2792',
#     'D2794',
#     'D2542',
#     'D2543',
#     'D2544',
#     'D2642',
#     'D2643',
#     'D2644',
#     'D2662',
#     'D2663',
#     'D2664',
#     'D2753'],
#    'services_remaining': 0,
#    'disclaimers': ['These services are subject to Individual and/or Consultant review.',
#     'Covered services are paid on seat date',
#     'Molars/Pre-molars are based upon the alternate benefit of a noble metal cast crown. Anterior teeth are based upon the alternate benefit of a porcelain fused to noble metal cast crown.',
#     'These codes are covered services only if placed to restore a tooth broken down due to tooth decay or injury resulting in the loss of tooth structure. (Injury does not include damage to teeth that results from chewing or biting food, substances or objects).',
#     '3/4 Crowns are not covered on anterior teeth. 3/4 Crown coverage is limited to Molar/Pre-molars.'],
#    'eligibility_details': [{'eligibility': 'ELIGIBLE',
#      'date': '11/27/2024',
#      'location': '1'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '2'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '3'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '4'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '5'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '6'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '7'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '8'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '9'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '10'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '11'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '12'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '13'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '14'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '15'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '16'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '17'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '18'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '19'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '20'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '21'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '22'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '23'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '24'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '25'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '26'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '27'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '28'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '29'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '30'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '31'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '32'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'A'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'B'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'C'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'D'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'E'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'F'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'G'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'H'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'I'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'J'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'K'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'L'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'M'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'N'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'O'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'P'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'Q'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'R'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'S'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'T'}]},
#   {'category': 'major',
#    'service_type': 'crown_repair',
#    'limitation': '1 per 24 consecutive months to the exact day',
#    'limitation_applies_to': ['D2980', 'D2981', 'D2982'],
#    'services_remaining': 0,
#    'disclaimers': ['Covered only if done more than 12 months after initial insertion of crown/onlay'],
#    'eligibility_details': [{'eligibility': 'ELIGIBLE',
#      'date': '11/27/2024',
#      'location': '1'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '2'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '3'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '4'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '5'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '6'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '7'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '8'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '9'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '10'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '11'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '12'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '13'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '14'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '15'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '16'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '17'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '18'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '19'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '20'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '21'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '22'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '23'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '24'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '25'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '26'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '27'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '28'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '29'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '30'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '31'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '32'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'A'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'B'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'C'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'D'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'E'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'F'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'G'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'H'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'I'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'J'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'K'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'L'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'M'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'N'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'O'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'P'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'Q'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'R'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'S'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'T'}]},
#   {'category': 'basic',
#    'service_type': 'stainless_steel_crowns',
#    'limitation': '1 replacement every 60 months to the exact day',
#    'limitation_applies_to': ['D2928',
#     'D2929',
#     'D2930',
#     'D2931',
#     'D2932',
#     'D2933',
#     'D2934'],
#    'services_remaining': 0,
#    'disclaimers': ['Crowns replacing tooth structure lost from abrasion, attrition, abfraction and erosion are not covered.',
#     'If used as a temporary, not covered',
#     'If a permanent crown replaces a stainless steel/resin/prefabricated crown at a later date but before replacement restrictions allow, all new charges will be reduced by those already paid.'],
#    'eligibility_details': [{'eligibility': 'ELIGIBLE',
#      'date': '11/27/2024',
#      'location': '1'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '2'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '3'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '4'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '5'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '6'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '7'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '8'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '9'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '10'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '11'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '12'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '13'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '14'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '15'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '16'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '17'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '18'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '19'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '20'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '21'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '22'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '23'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '24'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '25'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '26'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '27'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '28'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '29'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '30'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '31'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '32'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'A'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'B'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'C'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'D'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'E'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'F'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'G'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'H'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'I'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'J'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'K'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'L'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'M'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'N'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'O'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'P'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'Q'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'R'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'S'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'T'}]},
#   {'category': 'major',
#    'service_type': 'crown_recements',
#    'limitation': '1 per 24 consecutive months to the exact day',
#    'limitation_applies_to': ['D2920'],
#    'services_remaining': 0,
#    'disclaimers': ['Covered only if done more than 12 months after initial insertion of crown/onlay'],
#    'eligibility_details': [{'eligibility': 'ELIGIBLE',
#      'date': '11/27/2024',
#      'location': '1'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '2'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '3'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '4'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '5'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '6'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '7'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '8'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '9'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '10'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '11'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '12'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '13'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '14'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '15'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '16'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '17'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '18'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '19'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '20'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '21'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '22'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '23'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '24'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '25'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '26'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '27'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '28'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '29'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '30'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '31'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '32'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'A'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'B'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'C'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'D'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'E'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'F'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'G'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'H'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'I'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'J'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'K'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'L'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'M'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'N'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'O'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'P'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'Q'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'R'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'S'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'T'}]},
#   {'category': 'basic',
#    'service_type': 'protective_restorations',
#    'limitation': 'None',
#    'limitation_applies_to': ['D2940'],
#    'services_remaining': 2147483647,
#    'disclaimers': ['D2940 is covered only if not performed on the same date as the permanent restoration.',
#     'Not to be used to report endodontic access closure.'],
#    'eligibility_details': [{'eligibility': 'ELIGIBLE', 'date': '11/27/2024'}]},
#   {'category': 'major',
#    'service_type': 'buildups',
#    'limitation': '1 replacement every 60 months to the exact day',
#    'limitation_applies_to': ['D2950'],
#    'services_remaining': 0,
#    'disclaimers': ['These services are subject to Individual and/or Consultant review.',
#     'Considered only when required for retention and preservation of tooth. No benefits payable if restorative procedures are not covered.',
#     'Buildups submitted with the same date of service as a full cast crown are considered. Please bill for the crown on the seat date and for the buildup on the date it is performed.'],
#    'eligibility_details': [{'eligibility': 'ELIGIBLE',
#      'date': '11/27/2024',
#      'location': '1'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '2'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '3'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '4'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '5'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '6'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '7'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '8'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '9'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '10'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '11'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '12'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '13'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '14'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '15'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '16'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '17'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '18'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '19'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '20'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '21'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '22'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '23'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '24'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '25'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '26'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '27'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '28'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '29'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '30'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '31'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '32'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'A'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'B'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'C'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'D'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'E'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'F'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'G'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'H'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'I'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'J'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'K'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'L'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'M'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'N'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'O'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'P'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'Q'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'R'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'S'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'T'}]},
#   {'category': 'basic',
#    'service_type': 'pulpotomy',
#    'limitation': 'Covered once per site per lifetime',
#    'limitation_applies_to': ['D3220'],
#    'services_remaining': 0,
#    'disclaimers': ['Not to be construed as the first stage of root canal therapy.'],
#    'eligibility_details': [{'eligibility': 'ELIGIBLE',
#      'date': '11/27/2024',
#      'location': 'A'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'B'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'C'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'D'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'E'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'F'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'G'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'H'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'I'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'J'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'K'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'L'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'M'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'N'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'O'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'P'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'Q'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'R'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'S'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'T'}]},
#   {'category': 'basic',
#    'service_type': 'pulpal_therapy',
#    'limitation': 'None',
#    'limitation_applies_to': ['D3230', 'D3240'],
#    'services_remaining': 2147483647,
#    'disclaimers': ['Covered for deciduous teeth only.'],
#    'eligibility_details': [{'eligibility': 'ELIGIBLE', 'date': '11/27/2024'}]},
#   {'category': 'basic',
#    'service_type': 'incomplete_endodontic_therapy',
#    'limitation': 'Other',
#    'limitation_applies_to': ['D3332'],
#    'services_remaining': 0,
#    'disclaimers': ['Please provide diagnostic x-rays and a narrative or office notes for review.'],
#    'eligibility_details': [{'eligibility': 'ELIGIBLE', 'date': '11/27/2024'}]},
#   {'category': 'basic',
#    'service_type': 'treatment_of_root_canal_obstruction',
#    'limitation': 'Other',
#    'limitation_applies_to': ['D3331'],
#    'services_remaining': 0,
#    'disclaimers': ['Please provide diagnostic x-rays and a narrative or office notes for review.'],
#    'eligibility_details': [{'eligibility': 'ELIGIBLE', 'date': '11/27/2024'}]},
#   {'category': 'basic',
#    'service_type': 'simple_endodontic_therapy',
#    'limitation': 'Covered once per site per lifetime',
#    'limitation_applies_to': ['D3310', 'D3320'],
#    'services_remaining': 0,
#    'disclaimers': ['Includes intra-operative x-rays.'],
#    'eligibility_details': [{'eligibility': 'ELIGIBLE',
#      'date': '11/27/2024',
#      'location': '1'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '2'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '3'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '4'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '5'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '6'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '7'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '8'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '9'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '10'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '11'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '12'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '13'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '14'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '15'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '16'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '17'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '18'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '19'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '20'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '21'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '22'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '23'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '24'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '25'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '26'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '27'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '28'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '29'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '30'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '31'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '32'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'A'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'B'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'C'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'D'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'E'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'F'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'G'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'H'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'I'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'J'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'K'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'L'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'M'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'N'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'O'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'P'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'Q'},
# ...
#    'eligibility_details': [{'eligibility': 'ELIGIBLE', 'date': '11/27/2024'}]},
#   {'category': 'orthodontics',
#    'service_type': 'noncovered_orthodontic_services',
#    'limitation': 'NA',
#    'limitation_applies_to': ['D8692', 'D8695'],
#    'services_remaining': 0,
#    'eligibility_details': [{'eligibility': 'NOT_ELIGIBLE'}]},
#   {'category': 'basic',
#    'service_type': 'palliative_treatment',
#    'limitation': 'NA',
#    'limitation_applies_to': ['D9110'],
#    'services_remaining': 0,
#    'disclaimers': ['Covered only if no other service (except x-rays) is provided during the visit',
#     'There is no age limitation for palliative treatments.'],
#    'eligibility_details': [{'eligibility': 'ELIGIBLE', 'date': '11/27/2024'}]},
#   {'category': 'basic',
#    'service_type': 'general_anesthesia',
#    'limitation': 'Other',
#    'limitation_applies_to': ['D9222', 'D9223', 'D9239', 'D9243'],
#    'services_remaining': 0,
#    'disclaimers': ['These services are subject to Individual and/or Consultant review based on service, complexity, and length of procedure.',
#     'General Anesthesia or IV Sedation is payable for: removal of impacted teeth or coronectomy, the removal of residual tooth roots and/or the surgical removal of 4 molars on the same day in four different quadrants',
#     'General Anesthesia or IV Sedation is also payable for: removal of dental cysts/tumors, multiple restorative services for Children under age 5, osseous surgery, bone grafting, removal of third molars in 3 or 4 different quadrants on the same day',
#     "General Anesthesia or IV Sedation isn't covered when: used for more than one hour, the service isn't covered, used for patient management.",
#     'A predetermination is recommended.'],
#    'eligibility_details': [{'eligibility': 'ELIGIBLE', 'date': '11/27/2024'}]},
#   {'category': 'basic',
#    'service_type': 'therapeutic_parenteral_drugs',
#    'limitation': 'Other',
#    'limitation_applies_to': ['D9610', 'D9612'],
#    'services_remaining': 0,
#    'disclaimers': ['Covered for antibiotic drug administration only. Please submit the name of the drug for review.',
#     'Covered only if performed in conjunction with General Anesthesia or IV Sedation.'],
#    'eligibility_details': [{'eligibility': 'ELIGIBLE', 'date': '11/27/2024'}]},
#   {'category': 'basic',
#    'service_type': 'consultations',
#    'limitation': '1 per 12 consecutive months to the exact day',
#    'limitation_applies_to': ['D9310'],
#    'services_remaining': 1,
#    'disclaimers': ['Limited to a specialist',
#     'Covered only if no other service (except x-rays) is provided during the visit'],
#    'eligibility_details': [{'eligibility': 'ELIGIBLE', 'date': '11/27/2024'}]},
#   {'category': 'basic',
#    'service_type': 'occlusal_guards',
#    'limitation': '1 per 36 consecutive months to the exact day',
#    'limitation_applies_to': ['D9944', 'D9945', 'D9946'],
#    'services_remaining': 1,
#    'eligibility_details': [{'eligibility': 'ELIGIBLE', 'date': '11/27/2024'}]},
#   {'category': 'preventive',
#    'service_type': 'occlusal_x_rays',
#    'limitation': '2 per calendar year',
#    'limitation_applies_to': ['D0240', 'D0706'],
#    'services_remaining': 2,
#    'disclaimers': ['D0706 is only payable when submitted by an x-ray facility.'],
#    'eligibility_details': [{'eligibility': 'ELIGIBLE', 'date': '11/27/2024'}]},
#   {'category': 'orthodontics',
#    'service_type': 'oral_facial_images',
#    'limitation': 'None',
#    'limitation_applies_to': ['D0350', 'D0703'],
#    'services_remaining': 2147483647,
#    'disclaimers': ['Photos/images for orthodontic purposes are considered under orthodontia benefits. Refer to Orthodontia benefits for more details.',
#     'Only one occurrence is payable on a single date of service.',
#     'D0703 is only payable when submitted by an x-ray facility.'],
#    'eligibility_details': [{'eligibility': 'ELIGIBLE', 'date': '11/27/2024'}]},
#   {'category': 'major',
#    'service_type': 'surgical_access_of_an_unerupted_tooth',
#    'limitation': 'Other',
#    'limitation_applies_to': ['D7280'],
#    'services_remaining': 0,
#    'eligibility_details': [{'eligibility': 'ELIGIBLE', 'date': '11/27/2024'}]},
#   {'category': 'major',
#    'service_type': 'placement_of_device_to_facilitate_eruption',
#    'limitation': 'Other',
#    'limitation_applies_to': ['D7283'],
#    'services_remaining': 0,
#    'eligibility_details': [{'eligibility': 'ELIGIBLE', 'date': '11/27/2024'}]},
#   {'category': 'basic',
#    'service_type': 'pin_retention',
#    'limitation': 'None',
#    'limitation_applies_to': ['D2951'],
#    'services_remaining': 2147483647,
#    'disclaimers': ['Covered only if submitted on the same date of service and same tooth as a crown or a 3+ surface filling, inlay, or onlay.',
#     'Only one occurrence per tooth is payable on a single date of service.'],
#    'eligibility_details': [{'eligibility': 'ELIGIBLE', 'date': '11/27/2024'}]},
#   {'category': 'major',
#    'service_type': 'post_and_cores',
#    'limitation': '1 replacement every 60 months to the exact day',
#    'limitation_applies_to': ['D2952', 'D2953', 'D2954', 'D2957'],
#    'services_remaining': 0,
#    'disclaimers': ['Post and Core is not payable unless there is history of root canal therapy.',
#     'Post and Core is not payable if restorative procedure is not covered.',
#     'These services are subject to Individual and/or Consultant review.',
#     'Indirectly fabricated post and core is considered at the prefabricated post and core rate.'],
#    'eligibility_details': [{'eligibility': 'ELIGIBLE',
#      'date': '11/27/2024',
#      'location': '1'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '2'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '3'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '4'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '5'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '6'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '7'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '8'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '9'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '10'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '11'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '12'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '13'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '14'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '15'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '16'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '17'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '18'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '19'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '20'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '21'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '22'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '23'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '24'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '25'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '26'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '27'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '28'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '29'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '30'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '31'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': '32'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'A'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'B'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'C'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'D'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'E'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'F'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'G'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'H'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'I'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'J'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'K'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'L'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'M'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'N'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'O'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'P'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'Q'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'R'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'S'},
#     {'eligibility': 'ELIGIBLE', 'date': '11/27/2024', 'location': 'T'}]},
#   {'category': 'major',
#    'service_type': 'post_removal',
#    'limitation': 'None',
#    'limitation_applies_to': ['D2955'],
#    'services_remaining': 2147483647,
#    'disclaimers': ['Please submit diagnostic x-rays for review.',
#     'These services are subject to Individual and/or Consultant review.'],
#    'eligibility_details': [{'eligibility': 'ELIGIBLE', 'date': '11/27/2024'}]},
#   {'category': 'major',
#    'service_type': 'frenulectomy',
#    'limitation': 'Other',
#    'limitation_applies_to': ['D7961', 'D7963'],
#    'services_remaining': 0,
#    'disclaimers': ['These services are subject to Individual and/or Consultant review.',
#     'Please provide x-rays, photos, and clinical narrative for review.'],
#    'eligibility_details': [{'eligibility': 'ELIGIBLE', 'date': '11/27/2024'}]},
#   {'category': 'major',
#    'service_type': 'lingual_frenulectomy',
#    'limitation': 'Other',
#    'limitation_applies_to': ['D7962'],
#    'services_remaining': 0,
#    'disclaimers': ['These services are subject to Individual and/or Consultant review.',
#     'Please provide x-rays, photos, and clinical narrative for review.'],
#    'eligibility_details': [{'eligibility': 'ELIGIBLE', 'date': '11/27/2024'}]},
#   {'category': 'major',
#    'service_type': 'alveoplasty',
#    'limitation': 'Other',
#    'limitation_applies_to': ['D7310', 'D7311', 'D7320', 'D7321'],
#    'services_remaining': 0,
#    'disclaimers': ['These services are subject to Individual and/or Consultant review.',
#     'Radiographs must verify need to substantially reshape alveolar bone in preparation for a fixed or removable prosthetic'],
#    'eligibility_details': [{'eligibility': 'ELIGIBLE', 'date': '11/27/2024'}]},
#   {'category': 'basic',
#    'service_type': 'soft_biopsy',
#    'limitation': 'Other',
#    'limitation_applies_to': ['D7284', 'D7286', 'D7288'],
#    'services_remaining': 0,
#    'disclaimers': ['We do not cover biopsies of the lip, cheek, tongue, or any area outside of the oral cavity.',
#     'Please provide a path report, description and location of the procedure performed and x-rays or photos.'],
#    'eligibility_details': [{'eligibility': 'ELIGIBLE', 'date': '11/27/2024'}]},
#   {'category': 'major',
#    'service_type': 'hard_biopsy',
#    'limitation': 'Other',
#    'limitation_applies_to': ['D7285'],
#    'services_remaining': 0,
#    'disclaimers': ['We do not cover biopsies of the lip, cheek, tongue, or any area outside of the oral cavity.',
#     'Please provide a path report, description and location of the procedure performed and x-rays or photos.'],
#    'eligibility_details': [{'eligibility': 'ELIGIBLE', 'date': '11/27/2024'}]},
#   {'category': 'basic',
#    'service_type': 'incision_and_drainage_abscess',
#    'limitation': 'Other',
#    'limitation_applies_to': ['D7510'],
#    'services_remaining': 0,
#    'disclaimers': ['A separate benefit is not considered if done on the same day as an extraction.'],
#    'eligibility_details': [{'eligibility': 'ELIGIBLE', 'date': '11/27/2024'}]},
#   {'category': 'basic',
#    'service_type': 'pulp_vitality_tests',
#    'limitation': 'Other',
#    'limitation_applies_to': ['D0460'],
#    'services_remaining': 0,
#    'disclaimers': ['We allow one D0460 per date of service.'],
#    'eligibility_details': [{'eligibility': 'ELIGIBLE',
#      'date': '11/27/2024'}]}],
#  'not_covered': [{'category': 'not_covered',
#    'service_type': 'implant_body',
#    'limitation_applies_to': ['D6010', 'D6013', 'D6040', 'D6050']},
#   {'category': 'not_covered',
#    'service_type': 'implant_supporting_structures',
#    'limitation_applies_to': ['D6056', 'D6057']},
#   {'category': 'not_covered',
#    'service_type': 'bone_replacement_graft_at_the_time_of_implant',
#    'limitation_applies_to': ['D6104']},
#   {'category': 'not_covered',
#    'service_type': 'implant_removal',
#    'limitation_applies_to': ['D6100', 'D6105']},
#   {'category': 'not_covered',
#    'service_type': 'implant_supported_connecting_bar',
#    'limitation_applies_to': ['D6055']},
#   {'category': 'not_covered',
#    'service_type': 'maintenance_or_scaling_and_debridement_of_an_implant',
#    'limitation_applies_to': ['D6080', 'D6081']},
#   {'category': 'not_covered',
#    'service_type': 'repair_implant_abutment_remove_broken_implant_screw',
#    'limitation_applies_to': ['D6089', 'D6095', 'D6096', 'D6197']},
#   {'category': 'not_covered',
#    'service_type': 'treatment_of_peri_implant_defect',
#    'limitation_applies_to': ['D6101', 'D6102', 'D6103']},
#   {'category': 'not_covered',
#    'service_type': 'harmful_habit_appliance',
#    'limitation_applies_to': ['D8210', 'D8220'],
#    'disclaimers': ['Considered only for dependent children under age 18']},
#   {'category': 'not_covered',
#    'service_type': 'bone_replacement_graft_ridge_preservation',
#    'limitation_applies_to': ['D7953'],
#    'disclaimers': ['This bone graft code should not be billed if the tooth is still present.']},
#   {'category': 'not_covered',
#    'service_type': 'non_covered',
#    'limitation_applies_to': ['D0171',
#     'D0367',
#     'D0431',
#     'D1330',
#     'D2962',
#     'D3110',
#     'D3120',
#     'D3911',
#     'D4266',
#     'D4322',
#     'D4323',
#     'D4381',
#     'D5820',
#     'D5821',
#     'D6198',
#     'D7298',
#     'D7299',
#     'D7300',
#     'D7880',
#     'D7950',
#     'D7951',
#     'D7952',
#     'D9230',
#     'D9248',
#     'D9912',
#     'D9941',
#     'D9947',
#     'D9948',
#     'D9949',
#     'D9995',
#     'D9996'],
#    'disclaimers': ['This is a list of commonly asked about codes that are not covered. This is not an all-inclusive list of non-covered codes.',
#     'Payer does not provide benefits for any treatment or service that is: primarily cosmetic, temporary, replacing tooth structure lost from abrasion, attrition, erosion or abfraction, not reasonably expected to successfully correct a dental condition for at least 3 years']}],
#  'disclaimers': ['This plan has a missing tooth clause that may apply to the initial placement of full or partial dentures, fixed bridges, implants, and implant crowns. A predetermination is recommended to determine benefits.',
#   'The patient should see an In Network dentist for the best benefit. Lesser benefits are available by visiting a non-participating dentist. A different fee schedule may apply according to leased agreements. Benefits for non-participating Dentists are subject to Usual, Customary and Reasonable Fees (UCR). Call 800-247-4695 to check participation.',
#   'Predeterminations are not required prior to services being rendered. A predetermination may be recommended for certain services',
#   'Coordination of Benefits are determined by the Standard/Birthday Rule as defined by NAIC',
#   'Implants are allowed for patients 16 and over only.',
#   'Dependent dental will be terminated when dependent has turned 26 years old.',
#   'Orthodontic treatment is considered for all persons, regardless of age.']}

# %%
data.keys()
# Out:
# dict_keys(['onederfulId', 'payer_uuid', 'patient', 'subscriber', 'plan', 'deductible', 'maximums', 'coinsurance', 'limitations', 'not_covered', 'disclaimers'])

# %%
data['onederfulId']
# Out:
# '1234567890'

# %%
data['payer_uuid']
# Out:
# '0987654321'

# %%
data['patient']
# Out:
# {'member_id': '1234567890',
#  'address': {'street1': '1234 ANY CT',
#   'city': 'NYC',
#   'zip': '11111',
#   'state': 'NY'},
#  'coverage': {'effective_date': '01/01/2024', 'status': 'active'},
#  'name': 'TEST PERSON',
#  'first_name': 'TEST',
#  'last_name': 'PERSON',
#  'dob': '01/01/2011'}

# %%
data['subscriber']
# Out:
# {'name': 'TEST PERSON',
#  'first_name': 'TEST',
#  'last_name': 'PERSON',
#  'dob': '01/01/2011',
#  'member_id': '1234567890',
#  'address': {'street1': '1234 ANY CT',
#   'city': 'NYC',
#   'zip': '11111',
#   'state': 'NY'},
#  'coverage': {'effective_date': '01/01/2024', 'status': 'active'}}

# %%
subscriber_df = pd.DataFrame(data['subscriber'])
address_expanded = subscriber_df['address'].apply(pd.Series)
coverage_expanded = subscriber_df['coverage'].apply(pd.Series)
subscriber_df_2 = pd.concat([subscriber_df.drop(columns=['address', 'coverage']), address_expanded, coverage_expanded], axis=1)

# %%
coverage_expanded
# Out:
#                          0
# street1                NaN
# city                   NaN
# zip                    NaN
# state                  NaN
# effective_date  01/01/2024
# status              active

# %%
data['plan']
# Out:
# {'name': 'DENTAL',
#  'number': '12345',
#  'type': 'THE PLAN DENTAL PPO',
#  'group_number': '10001',
#  'state': 'GA',
#  'period': 'calendar'}

# %%
deductible_df = pd.DataFrame(data['deductible'])
deductible_df
# Out:
#            network         category plan_period  amount coverage_level
# 0       in_network       preventive    calendar    0.00     individual
# 1       in_network  basic_and_major    calendar   50.00     individual
# 2       in_network       preventive   remaining    0.00     individual
# 3       in_network  basic_and_major   remaining   50.00     individual
# 4       in_network       preventive    calendar    0.00         family
# 5       in_network  basic_and_major    calendar  150.00         family
# 6       in_network       preventive   remaining    0.00         family
# 7       in_network  basic_and_major   remaining  150.00         family
# 8   out_of_network       preventive    calendar    0.00     individual
# 9   out_of_network  basic_and_major    calendar   50.00     individual
# 10  out_of_network       preventive   remaining    0.00     individual
# 11  out_of_network  basic_and_major   remaining   50.00     individual
# 12  out_of_network       preventive    calendar    0.00         family
# 13  out_of_network  basic_and_major    calendar  150.00         family
# 14  out_of_network       preventive   remaining    0.00         family
# 15  out_of_network  basic_and_major   remaining  150.00         family

# %%
maximum_df = pd.DataFrame(data['maximums'])
maximum_df
# Out:
#           network                    category         plan_period   amount
# 0      in_network                orthodontics            lifetime  1500.00
# 1      in_network  preventive_basic_and_major            calendar  1500.00
# 2      in_network                orthodontics  lifetime_remaining  1500.00
# 3      in_network  preventive_basic_and_major           remaining  1280.00
# 4  out_of_network                orthodontics            lifetime  1500.00
# 5  out_of_network  preventive_basic_and_major            calendar  1500.00
# 6  out_of_network                orthodontics  lifetime_remaining  1500.00
# 7  out_of_network  preventive_basic_and_major           remaining  1280.00

# %%
coinsurance_df = pd.DataFrame(data['coinsurance'])
coinsurance_df
# Out:
#           network      category plan_period percent
# 0      in_network    preventive    calendar     100
# 1      in_network         basic    calendar      90
# 2      in_network         major    calendar      60
# 3      in_network  orthodontics    lifetime      50
# 4  out_of_network    preventive    calendar     100
# 5  out_of_network         basic    calendar      90
# 6  out_of_network         major    calendar      60
# 7  out_of_network  orthodontics    lifetime      50

# %%
limitation_df['service_dates'].values[0]
# Out:
# [{'procedure_code': 'D0120', 'service_date': '01/01/2024'}]

# %%
limitation_df = pd.DataFrame(data['limitations'])
limitation_df['service_dates'] = limitation_df['service_dates'].apply(
    lambda x: [f"{d['procedure_code']} : ({d['service_date']})" for d in x] if isinstance(x, list) else ''
)
limitation_df['eligibility_details'] = limitation_df['eligibility_details'].apply(
    lambda x: [
        f"{d['eligibility']} : ({d['date']})" if 'date' in d else f"{d['eligibility']}" 
        for d in x
    ] if isinstance(x, list) else ''
)
limitation_df.head(2).style
# Out:
# <style type="text/css">
# </style>
# <table id="T_59d4f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_59d4f_level0_col0" class="col_heading level0 col0" >category</th>
#       <th id="T_59d4f_level0_col1" class="col_heading level0 col1" >service_type</th>
#       <th id="T_59d4f_level0_col2" class="col_heading level0 col2" >limitation</th>
#       <th id="T_59d4f_level0_col3" class="col_heading level0 col3" >limitation_applies_to</th>
#       <th id="T_59d4f_level0_col4" class="col_heading level0 col4" >service_dates</th>
#       <th id="T_59d4f_level0_col5" class="col_heading level0 col5" >services_remaining</th>
#       <th id="T_59d4f_level0_col6" class="col_heading level0 col6" >disclaimers</th>
#       <th id="T_59d4f_level0_col7" class="col_heading level0 col7" >eligibility_details</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_59d4f_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_59d4f_row0_col0" class="data row0 col0" >preventive</td>
#       <td id="T_59d4f_row0_col1" class="data row0 col1" >examinations</td>
#       <td id="T_59d4f_row0_col2" class="data row0 col2" >2 per calendar year</td>
#       <td id="T_59d4f_row0_col3" class="data row0 col3" >['D0120', 'D0145', 'D0150', 'D0160', 'D0170', 'D0180', 'D9430']</td>
#       <td id="T_59d4f_row0_col4" class="data row0 col4" >['D0120 : (01/01/2024)']</td>
#       <td id="T_59d4f_row0_col5" class="data row0 col5" >1</td>
#       <td id="T_59d4f_row0_col6" class="data row0 col6" >['D9430 is covered only if no other service is provided during the visit.', 'Maximum benefit payable for a D0150 submitted for an established patient may be based on a D0120.']</td>
#       <td id="T_59d4f_row0_col7" class="data row0 col7" >['ELIGIBLE : (11/27/2024)']</td>
#     </tr>
#     <tr>
#       <th id="T_59d4f_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_59d4f_row1_col0" class="data row1 col0" >basic</td>
#       <td id="T_59d4f_row1_col1" class="data row1 col1" >limited_examinations</td>
#       <td id="T_59d4f_row1_col2" class="data row1 col2" >2 per calendar year</td>
#       <td id="T_59d4f_row1_col3" class="data row1 col3" >['D0140']</td>
#       <td id="T_59d4f_row1_col4" class="data row1 col4" >['D0120 : (01/01/2024)']</td>
#       <td id="T_59d4f_row1_col5" class="data row1 col5" >1</td>
#       <td id="T_59d4f_row1_col6" class="data row1 col6" >['Limited oral evaluation is considered with or without other procedures on same date of service.']</td>
#       <td id="T_59d4f_row1_col7" class="data row1 col7" >['ELIGIBLE : (11/27/2024)']</td>
#     </tr>
#   </tbody>
# </table>

# %%
exception_df = pd.DataFrame(data['not_covered'])
exception_df
# Out:
#        category                                       service_type  \
# 0   not_covered                                       implant_body
# 1   not_covered                      implant_supporting_structures
# 2   not_covered      bone_replacement_graft_at_the_time_of_implant
# 3   not_covered                                    implant_removal
# 4   not_covered                   implant_supported_connecting_bar
# 5   not_covered  maintenance_or_scaling_and_debridement_of_an_i...
# 6   not_covered  repair_implant_abutment_remove_broken_implant_...
# 7   not_covered                   treatment_of_peri_implant_defect
# 8   not_covered                            harmful_habit_appliance
# 9   not_covered          bone_replacement_graft_ridge_preservation
# 10  not_covered                                        non_covered
#
#                                 limitation_applies_to  \
# 0                        [D6010, D6013, D6040, D6050]
# 1                                      [D6056, D6057]
# 2                                             [D6104]
# 3                                      [D6100, D6105]
# 4                                             [D6055]
# 5                                      [D6080, D6081]
# 6                        [D6089, D6095, D6096, D6197]
# 7                               [D6101, D6102, D6103]
# 8                                      [D8210, D8220]
# 9                                             [D7953]
# 10  [D0171, D0367, D0431, D1330, D2962, D3110, D31...
#
#                                           disclaimers
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8   [Considered only for dependent children under ...
# 9   [This bone graft code should not be billed if ...
# 10  [This is a list of commonly asked about codes ...

# %%
disclaimer_df = pd.DataFrame([{'disclaimer': d} for d in data['disclaimers']])
disclaimer_df
# Out:
#                                           disclaimer
# 0  This plan has a missing tooth clause that may ...
# 1  The patient should see an In Network dentist f...
# 2  Predeterminations are not required prior to se...
# 3  Coordination of Benefits are determined by the...
# 4  Implants are allowed for patients 16 and over ...
# 5  Dependent dental will be terminated when depen...
# 6  Orthodontic treatment is considered for all pe...
